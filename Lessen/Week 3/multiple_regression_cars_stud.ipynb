# %% [markdown]
# # Multiple linear regression

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# In this assignment, we will use data from a dataset with car data. We're going to predict the price of a car.
# 1. Start with reading the data and analyse the first rows

# %%
df = pd.read_csv('cars.csv')
df.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0           2010    gasoline           False    gasoline              2.5
# 1           2002    gasoline           False    gasoline              3.0
# 2           2001    gasoline           False    gasoline              2.5
# 3           1999    gasoline           False    gasoline              3.0
# 4           2001    gasoline           False    gasoline              2.5
#
#    ... feature_1  feature_2 feature_3 feature_4  feature_5  feature_6  \
# 0  ...      True       True      True     False       True      False
# 1  ...      True      False     False      True       True      False
# 2  ...      True      False     False     False      False      False
# 3  ...     False      False     False     False      False      False
# 4  ...      True      False      True      True      False      False
#
#   feature_7  feature_8  feature_9  duration_listed
# 0      True       True       True               16
# 1     False      False       True               83
# 2     False       True       True              151
# 3     False      False      False               86
# 4     False      False       True                7
#
# [5 rows x 30 columns]

# %% [markdown]
# 2. Check for more info on the variables: nr of rows, NaN, mean etc. And delete variables of which metadata is missing.

# %%
df.dropna()
# Out:
#       manufacturer_name  model_name transmission   color  odometer_value  \
# 0                Subaru     Outback    automatic  silver          190000
# 1                Subaru     Outback    automatic    blue          290000
# 2                Subaru    Forester    automatic     red          402000
# 3                Subaru     Impreza   mechanical    blue           10000
# 4                Subaru      Legacy    automatic   black          280000
# ...                 ...         ...          ...     ...             ...
# 38526          Chrysler         300    automatic  silver          290000
# 38527          Chrysler  PT Cruiser   mechanical    blue          321000
# 38528          Chrysler         300    automatic    blue          777957
# 38529          Chrysler  PT Cruiser   mechanical   black           20000
# 38530          Chrysler     Voyager    automatic  silver          297729
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0               2010    gasoline           False    gasoline              2.5
# 1               2002    gasoline           False    gasoline              3.0
# 2               2001    gasoline           False    gasoline              2.5
# 3               1999    gasoline           False    gasoline              3.0
# 4               2001    gasoline           False    gasoline              2.5
# ...              ...         ...             ...         ...              ...
# 38526           2000    gasoline           False    gasoline              3.5
# 38527           2004      diesel           False      diesel              2.2
# 38528           2000    gasoline           False    gasoline              3.5
# 38529           2001    gasoline           False    gasoline              2.0
# 38530           2000    gasoline           False    gasoline              2.4
#
#        ... feature_1  feature_2 feature_3 feature_4  feature_5  feature_6  \
# 0      ...      True       True      True     False       True      False
# 1      ...      True      False     False      True       True      False
# 2      ...      True      False     False     False      False      False
# 3      ...     False      False     False     False      False      False
# 4      ...      True      False      True      True      False      False
# ...    ...       ...        ...       ...       ...        ...        ...
# 38526  ...      True      False     False      True       True      False
# 38527  ...      True      False     False      True       True      False
# 38528  ...      True      False     False      True       True      False
# 38529  ...      True      False     False     False      False      False
# 38530  ...     False      False     False     False      False      False
#
#       feature_7  feature_8  feature_9  duration_listed
# 0          True       True       True               16
# 1         False      False       True               83
# 2         False       True       True              151
# 3         False      False      False               86
# 4         False      False       True                7
# ...         ...        ...        ...              ...
# 38526     False       True       True              301
# 38527     False       True       True              317
# 38528     False       True       True              369
# 38529     False      False       True              490
# 38530     False      False       True              632
#
# [38521 rows x 30 columns]

# %% [markdown]
# 3. Visualize variables which raise questions, since some of the data looks extreme. Analyse possible erroneous data and drop these rows.

# %%
sns.boxplot(x='duration_listed', data=df)
plt.show()
sns.displot(x='duration_listed', kde=True, data=df)
plt.show()

# %%
df_select = df[df['price_usd'] <  100]
df_select.head(11)
# Out:
#       manufacturer_name    model_name transmission   color  odometer_value  \
# 8230                ВАЗ          2105   mechanical     red          999999
# 8263                ВАЗ          2109   mechanical    blue          225477
# 8770               Fiat         Palio   mechanical     red          260000
# 12809           Renault            19   mechanical    blue           99999
# 12810           Renault            19   mechanical    blue           99999
# 16205        Volkswagen         Jetta   mechanical  silver             200
# 16406        Volkswagen  T4 Caravelle   mechanical   white               1
# 27570               BMW           523   mechanical    blue          450000
# 30149             Mazda           626   mechanical   black          300000
# 34365     Mercedes-Benz            T1   mechanical   white          450000
# 36634           Peugeot           406   mechanical    blue          200000
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 8230            1991    gasoline           False    gasoline              1.2
# 8263            1991    gasoline           False    gasoline              1.3
# 8770            1998    gasoline           False    gasoline              1.6
# 12809           1992    gasoline           False    gasoline              1.7
# 12810           1992    gasoline           False    gasoline              1.7
# 16205           1996    gasoline           False    gasoline              1.8
# 16406           1995      diesel           False      diesel              2.4
# 27570           1999    gasoline           False    gasoline              2.5
# 30149           1987    gasoline           False    gasoline              2.0
# 34365           1990      diesel           False      diesel              2.9
# 36634           1997    gasoline           False    gasoline              1.6
#
#        ... feature_1  feature_2 feature_3 feature_4  feature_5  feature_6  \
# 8230   ...     False      False     False     False      False      False
# 8263   ...     False      False     False     False      False       True
# 8770   ...     False      False     False     False      False      False
# 12809  ...     False      False     False     False      False      False
# 12810  ...     False      False     False     False      False      False
# 16205  ...     False      False     False     False      False      False
# 16406  ...     False      False     False     False      False      False
# 27570  ...     False      False     False      True       True      False
# 30149  ...     False      False     False     False      False      False
# 34365  ...     False      False     False     False      False      False
# 36634  ...     False      False     False     False      False      False
#
#       feature_7  feature_8  feature_9  duration_listed
# 8230      False      False      False                1
# 8263      False       True      False               14
# 8770      False      False      False                2
# 12809     False      False      False                3
# 12810     False      False      False                3
# 16205     False      False      False                2
# 16406     False      False      False                3
# 27570     False      False      False                1
# 30149     False      False       True                0
# 34365     False      False      False                2
# 36634     False      False      False                1
#
# [11 rows x 30 columns]

# %% [markdown]
# ## Selecting variables
#
# By looking at the correlations between *price* and the other variables, we can decide which variables to include.
#
# 4. Calculate the correlation of the numerical variables and also show them in a pairplot. Drop variables with very low correlations

# %% [markdown]
# 5. Let's include the categorical variables which probably influence the price. You will need to convert them to dummies. First check the categories if you don't know what values they contain. Finally drop the categorical data you don't want to include.

# %% [markdown]
# 6. Check for NA's and drop them

# %% [markdown]
# ## Fitting the model

# %% [markdown]
# We will split our data, train our model and then test it.
#
# 7. Let's first create the *X* and *y* variables.

# %% [markdown]
# 8. Split the data in 70/30, 70% training set and 30% test set.

# %% [markdown]
# 9. Now let's create the model and train it. Also calculate the intercept and slopes

# %% [markdown]
# Going from the general formula of $ y = b_0 + b_1x_1 + b_2x_2 + b_3x_3 .. b_nx_n + e$

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# 10. Now let's evaluate the model's performance. We'll start by calculating the  R2 and next the RMSE

# %% [markdown]
# 11. Let's plot the predictions to see where our model predicts best.
