# %% [markdown]
# ## Funda cleaning and feature selection
#
# We want to create a model which predicts house prices. But first we need to do some cleaning and find an independent variable which highly correlates with price

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('funda.csv')
df.head()
# Out:
#    id                         address  area  bedrooms postal_code  \
# 0   0       Knollendamstraat 4 III/IV   108         2     1013 TN
# 1   1             Moerdijkstraat 47 1    47         1     1079 XM
# 2   2               Zeeburgerdijk 349   116         2     1095 AD
# 3   3          Brederodestraat 124 -1    58         2     1054 VH
# 4   4  Admiraal De Ruijterweg 409 III    63         1     1055 MD
#
#   posting_date   price property_type  rooms  sale_date  \
# 0     4-6-2016  510000     apartment      3  23-6-2016
# 1    22-6-2016  215000     apartment      2   5-7-2016
# 2     9-6-2016  325000     apartment      3   8-7-2016
# 3    14-5-2016  315000     apartment      3   2-6-2016
# 4    14-6-2016  200000     apartment      3  23-6-2016
#
#                                                  url  year_built
# 0  http://www.funda.nl/koop/verkocht/amsterdam/ap...        1906
# 1  http://www.funda.nl/koop/verkocht/amsterdam/ap...        1938
# 2  http://www.funda.nl/koop/verkocht/amsterdam/ap...        2003
# 3  http://www.funda.nl/koop/verkocht/amsterdam/ap...        1910
# 4  http://www.funda.nl/koop/verkocht/amsterdam/ap...        1906

# %% [markdown]
# 1. Start with plotting price (dependent variable) versus to other variables. first create a subset of df with only price and the other two variables and next create a <b>pairplot</b>.

# %%
df_sel = df[['area', 'rooms', 'price']]
sns.pairplot(df_sel)
plt.show()

# %% [markdown]
# 2. It's clear that something is wrong with some of the prices, as they are 0 (or close to 0). Let's plot price in a histogram and boxplot.

# %%
sns.boxplot(x='price', data=df)
plt.show()
sns.displot(x='price', kde=True, data =df)
plt.show()

# %% [markdown]
# 3. Also plot the other variables and check for outliers, which you don't want to incorporate in your model.

# %%
# sns.boxplot(x='count', data=df)
# plt.show()
# sns.displot(x='area', kde=True, data =df)
# plt.show()

# %% [markdown]
# 4. Check the outliers in your code, by subsetting and analysing the data.

# %%
df_outlines = df[(df['area'] > 500)].sort_values(by='area', ascending=False)
df_outlines.head()
# Out:
#         id            address  area  bedrooms postal_code posting_date  price  \
# 5972  5972    Herengracht 203   806         5     1016 BE   25-10-2014   3250
# 1397  1397   Prinseneiland 93   663         8     1013 LM    25-3-2016   2500
# 8278  8278   Prinseneiland 89   646         9     1013 LM    16-9-2015   2550
# 9499  9499  Sarphatistraat 11   644         4     1017 WS    25-4-2015   2750
# 462    462      Apollolaan 11   614         6     1077 AA    16-6-2016   4250
#
#      property_type  rooms   sale_date  \
# 5972         house     12  23-11-2015
# 1397         house     14   18-5-2016
# 8278         house     11   1-10-2015
# 9499         house     11    2-9-2015
# 462          house     14   29-6-2016
#
#                                                     url  year_built
# 5972  http://www.funda.nl/koop/verkocht/amsterdam/hu...        1906
# 1397  http://www.funda.nl/koop/verkocht/amsterdam/hu...        1882
# 8278  http://www.funda.nl/koop/verkocht/amsterdam/hu...        1892
# 9499  http://www.funda.nl/koop/verkocht/amsterdam/hu...        1906
# 462   http://www.funda.nl/koop/verkocht/amsterdam/hu...        1906

# %%
df_outlines = df[(df['area'] < 20)].sort_values(by='area', ascending=True)
df_outlines.head()
# Out:
#         id               address  area  bedrooms postal_code posting_date  \
# 6891  6891    Europaboulevard 59     1         7     1083 AD    25-9-2014
# 6790  6790  Prinsengracht 1079 E    18         1     1017 JH    12-9-2015
#
#        price property_type  rooms   sale_date  \
# 6891    1250         house     11  18-11-2015
# 6790  125000     apartment      1   2-11-2015
#
#                                                     url  year_built
# 6891  http://www.funda.nl/koop/verkocht/amsterdam/hu...        2014
# 6790  http://www.funda.nl/koop/verkocht/amsterdam/ap...        1700

# %%
df_outlines = df[(df['rooms'] > 8)].sort_values(by='area', ascending=True)
df_outlines.head()
# Out:
#         id                 address  area  bedrooms postal_code posting_date  \
# 6891  6891      Europaboulevard 59     1         7     1083 AD    25-9-2014
# 4622  4622          Kerkstraat 130   139         4     1017 GP     8-1-2016
# 4262  4262           Holtmeulen 51   157         7     1083 CG    23-9-2015
# 8970  8970  Amstelveenseweg 156 BV   169         8     1075 XN     5-8-2015
# 5498  5498          Sloterweg 1121   180         5     1066 CE     5-6-2015
#
#        price property_type  rooms   sale_date  \
# 6891    1250         house     11  18-11-2015
# 4622  649000         house      9   21-1-2016
# 4262  515000         house      9    1-3-2016
# 8970  700000     apartment      9   20-8-2015
# 5498  800000         house     10  26-10-2015
#
#                                                     url  year_built
# 6891  http://www.funda.nl/koop/verkocht/amsterdam/hu...        2014
# 4622  http://www.funda.nl/koop/verkocht/amsterdam/hu...        1685
# 4262  http://www.funda.nl/koop/verkocht/amsterdam/hu...        1962
# 8970  http://www.funda.nl/koop/verkocht/amsterdam/ap...        1880
# 5498  http://www.funda.nl/koop/verkocht/amsterdam/hu...        1906

# %% [markdown]
# 5. Create a subset with the data you want to incorporate in your model. And create another pairplot

# %%
df = df[(df['price'] > 30000) & (df['area'] > 10)]
df_sel = df[['area', 'rooms', 'price']]

sns.pairplot(df_sel)
plt.show()

# %% [markdown]
# 6. Calculate the correlations using:  <i>corr=df[[var1,var2,var3]].corr()</i>

# %%
corr = df[['price', 'area', 'rooms']].corr()
corr
# Out:
#           price      area     rooms
# price  1.000000  0.725081  0.540556
# area   0.725081  1.000000  0.781526
# rooms  0.540556  0.781526  1.000000

# %% [markdown]
# 7. Run the code below for a heatmap

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap="YlGnBu") #the last two arguments set the column names
plt.show()

# %% [markdown]
# 8. Another graph we have not used yet is <b>lmplot</b> (linear model plot), which shows the datapoints and a regression line. Focus on the independent variable <b>area</b> and dependent variable <b>price</b>. Use the attribute <i>scatter_kws={'s':3,'alpha':0.2}</i> to change the style of the data points.

# %%
sns.lmplot(x='area', y='price', scatter_kws={'s':3, 'alpha':0.2}, data=df)
plt.xlabel('Area (m2)')
plt.ylabel('Price in euros')
plt.show()

# %% [markdown]
# 9. finally check the significance of the correlation

# %%
from scipy.stats.stats import pearsonr #We will need the correlation function from the scientific package scipy
print(pearsonr(df_sel['area'],df_sel['price']))
# Out:
# (0.7250807666953664, 0.0)

# %% [markdown]
# This is a strong correlation (0.73) which is highly significant (p < 0.0001)
